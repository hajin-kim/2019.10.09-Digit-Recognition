# %% [markdown]
# # Digit Recognition with CNN
#
# Reference
# <br>
# https://pinkwink.kr/1121
# <br>
# http://adventuresinmachinelearning.com/keras-tutorial-cnn-11-lines/
# <br>
# <br>
# Structure of convolutional neural network(CNN)
# <br>
# <img src=https://i0.wp.com/adventuresinmachinelearning.com/wp-content/uploads/2017/04/CNN-example-block-diagram.jpg>
# <br>

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# import tensorflow, keras, numpy
import sys
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
import numpy as np
np.random.seed(7)
# Out:
# Using TensorFlow backend.

# %%
# check version
print('Python version : ', sys.version)
print('TensorFlow version : ', tf.__version__)
print('Keras version : ', keras.__version__)
# Out:
# Python version :  3.6.8 (default, Jan 14 2019, 11:02:34)
# [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]]
# TensorFlow version :  1.15.0-rc3
# Keras version :  2.2.5

# %%
# image shape
img_rows = 28
img_cols = 28
input_shape = (img_rows, img_cols, 1)

# load data from keras mnist datasets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# reshape datas
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)

# change type to floating point
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

batch_size = 128
num_classes = 10
epochs = 12

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
# # check data info
# print('x_train shape:', x_train.shape)
# print(x_train.shape[0], 'train samples')
# print(x_test.shape[0], 'test samples')

# %%
# init model
model = tf.keras.Sequential([
    # layer 1
    tf.keras.layers.Conv2D(32, kernel_size=(5, 5), strides=(1, 1), padding='same', 
                           activation='relu', 
                           input_shape=input_shape),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    # layer 2
    tf.keras.layers.Conv2D(64, (2, 2), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Dropout(0.25),
    # flatten layer 1
    tf.keras.layers.Flatten(),
    # layer 2
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    # output layer
    tf.keras.layers.Dense(num_classes, activation='softmax'),
])

# see model info
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        8256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              3137000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 3,156,098
# Trainable params: 3,156,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# train
hist = model.fit(x_train, y_train,
                 batch_size=batch_size,
                 epochs=epochs,
                 verbose=1, 
                 validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 9s 149us/sample - loss: 0.1927 - acc: 0.9394 - val_loss: 0.0542 - val_acc: 0.9821
# Epoch 2/12
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.0601 - acc: 0.9815 - val_loss: 0.0352 - val_acc: 0.9886
# Epoch 3/12
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.0447 - acc: 0.9861 - val_loss: 0.0272 - val_acc: 0.9912
# Epoch 4/12
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0365 - acc: 0.9884 - val_loss: 0.0255 - val_acc: 0.9919
# Epoch 5/12
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0316 - acc: 0.9898 - val_loss: 0.0247 - val_acc: 0.9918
# Epoch 6/12
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0251 - acc: 0.9919 - val_loss: 0.0234 - val_acc: 0.9922
# Epoch 7/12
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0223 - acc: 0.9929 - val_loss: 0.0232 - val_acc: 0.9923
# Epoch 8/12
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0215 - acc: 0.9931 - val_loss: 0.0215 - val_acc: 0.9933
# Epoch 9/12
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0196 - acc: 0.9935 - val_loss: 0.0209 - val_acc: 0.9935
# Epoch 10/12
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.0154 - acc: 0.9949 - val_loss: 0.0225 - val_acc: 0.9928
# Epoch 11/12
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0159 - acc: 0.9946 - val_loss: 0.0254 - val_acc: 0.9913
# Epoch 12/12
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0140 - acc: 0.9953 - val_loss: 0.0234 - val_acc: 0.9928

# %% [markdown]
# Now model is ready.
# <br>
# Training is done.
# <br>

# %%
# see test result
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.023448841330297
# Test accuracy: 0.9928

# %%
# save model as file
model.save('DigitRecognitionCNNTF2.h5')

# %%
# # matplotlib for see choosen image
# import matplotlib.pyplot as plt

# # choose image and show
# n = 0
# plt.imshow(x_test[n].reshape(28, 28), cmap='Greys', interpolation='nearest')
# # plt.xticks([]) # hide x axis
# # plt.yticks([]) # hide y axis
# plt.show()

# # reshape choosen image and predict with trained model
# print('The Answer is ', model.predict_classes(x_test[n].reshape((1, 28, 28, 1))))

# %%
# '''
# choose random loss images and show prediction error
# '''
# import random

# predicted_result = model.predict(x_test)
# predicted_labels = np.argmax(predicted_result, axis=1)

# test_labels = np.argmax(y_test, axis=1)

# wrong_result = []

# for n in range(0, len(test_labels)):
#     if predicted_labels[n] != test_labels[n]:
#         wrong_result.append(n)

# samples = random.choices(population=wrong_result, k=16)

# count = 0
# nrows = ncols = 4

# plt.figure(figsize=(12,8))

# for n in samples:
#     count += 1
#     plt.subplot(nrows, ncols, count)
#     plt.imshow(x_test[n].reshape(28, 28), cmap='Greys', interpolation='nearest')
#     tmp = "Label:" + str(test_labels[n]) + ", Prediction:" + str(predicted_labels[n])
#     plt.title(tmp)

# plt.tight_layout()
# plt.show()
